# %%
import sys
import os.path as p

sys.path.append("/home/j-gunmo/desktop/00.my-project/17.P-Stage-T1003/4-STAGE/")

import easydict
from IPython.display import clear_output
from utils import get_args, get_root_dir

# %%
args = get_args()
args.data_dir = "../../input/data/train_dataset/"
args.root_dir = get_root_dir("../bert_last_test/")

args.num_workers = 2
args.n_epochs = 20
args.hidden_dim = 1024

# %%
import pickle

# %%
import torch
from trainer import DKTTrainer
from models.lstm.model import LSTM
from utils import get_criterion

class Loss1Trainer(DKTTrainer):  # 원래 코드
    def _collate_fn(self, batch):
        col_n = len(batch[0])
        col_list = [[] for _ in range(col_n)]
        max_seq_len = len(batch[0][-1])


        # batch의 값들을 각 column끼리 그룹화
        for row in batch:
            for i, col in enumerate(row):
                pre_padded = torch.zeros(max_seq_len)
                pre_padded[-len(col):] = col
                col_list[i].append(pre_padded)


        for i, _ in enumerate(col_list):
            col_list[i] =torch.stack(col_list[i])

        return tuple(col_list)


    def _process_batch(batch, args):

        #1 dataloader #2와 순서를 맞춰주자
        (correct, question, test, tag, time_diff, 
        head, mid, tail, mid_tail, 
        head_answerProb, mid_answerProb, tail_answerProb,
        mask) = batch


        # change to float
        mask = mask.type(torch.FloatTensor)
        correct = correct.type(torch.FloatTensor)

        #  interaction을 임시적으로 correct를 한칸 우측으로 이동한 것으로 사용
        #    saint의 경우 decoder에 들어가는 input이다
        interaction = correct + 1 # 패딩을 위해 correct값에 1을 더해준다.
        interaction = interaction.roll(shifts=1, dims=1)
        interaction_mask = mask.roll(shifts=1, dims=1)
        interaction_mask[:, 0] = 0 # set padding index to the first sequence
        interaction = (interaction * interaction_mask).to(torch.int64)
        # print(interaction)
        # exit()
        #  test_id, question_id, tag
        test = ((test + 1) * mask).to(torch.int64)
        question = ((question + 1) * mask).to(torch.int64)
        tag = ((tag + 1) * mask).to(torch.int64)

        #2 추가 feature
        # time_median = ((time_median + 1) * mask).type(torch.FloatTensor)
        head_answerProb = ((head_answerProb + 1) * mask).type(torch.FloatTensor)
        mid_answerProb = ((mid_answerProb + 1) * mask).type(torch.FloatTensor)
        tail_answerProb = ((tail_answerProb + 1) * mask).type(torch.FloatTensor)


        time_diff = ((time_diff + 1) * mask).to(torch.int64)
        head = ((head + 1) * mask).to(torch.int64)
        mid = ((mid + 1) * mask).to(torch.int64)
        tail = ((tail + 1) * mask).to(torch.int64)
        mid_tail = ((mid_tail + 1) * mask).to(torch.int64)

        # gather index
        # 마지막 sequence만 사용하기 위한 index
        gather_index = torch.tensor(np.count_nonzero(mask, axis=1))
        gather_index = gather_index.view(-1, 1) - 1


        #3 device memory로 이동

        test = test.to(args.device)
        question = question.to(args.device)
        tag = tag.to(args.device)
        correct = correct.to(args.device)

        # time_median = time_median.to(args.device)
        time_diff = time_diff.to(args.device)
        head = head.to(args.device)
        mid = mid.to(args.device)
        tail = tail.to(args.device)
        mid_tail = mid_tail.to(args.device)

        head_answerProb = head_answerProb.to(args.device)
        mid_answerProb = mid_answerProb.to(args.device)
        tail_answerProb = tail_answerProb.to(args.device)

        mask = mask.to(args.device)

        interaction = interaction.to(args.device)
        gather_index = gather_index.to(args.device)

        #4 
        return (test, question, tag, time_diff, head, mid, tail, mid_tail, 
                head_answerProb, mid_answerProb, tail_answerProb,
                mask, interaction, gather_index, correct)
    
class Loss2Trainer(Loss1Trainer):
    def _compute_loss(self, preds, targets):
        loss = get_criterion(preds, targets)
        loss = loss[:, -2:]
        loss = torch.mean(loss)
        return loss
    
class Loss5Trainer(Loss1Trainer):
    def _compute_loss(self, preds, targets):
        loss = get_criterion(preds, targets)
        loss = loss[:, -5:]
        loss = torch.mean(loss)  # scalar 형태가 아니면 loss.backward가 안된다.
        return loss
    
class Loss10Trainer(Loss1Trainer):
    def _compute_loss(self, preds, targets):
        loss = get_criterion(preds, targets)
        loss = loss[:, -10:]
        loss = torch.mean(loss)
        return loss
    
class LossAllTrainer(Loss1Trainer):
    def _compute_loss(self, preds, targets):
        loss = get_criterion(preds, targets)
        loss = torch.mean(loss)
        return loss
    
class Bert(nn.Module):
    def __init__(self, args):
        super(Bert, self).__init__()
        self.args = args
        self.args.numeric = False
        
        cate_size = len(self.args.cate_cols) + 1 # interaction
        cont_size = len(self.args.cont_cols) - 2


        #1 Embedding 
        # interaction은 현재 correct으로 구성되어있다. correct(1, 2) + padding(0)
        self.embedding_interaction = nn.Embedding(3, self.args.hidden_dim)
        self.embedding_test = nn.Embedding(self.args.n_cols['testId']+1, self.args.hidden_dim)
        self.embedding_question = nn.Embedding(self.args.n_cols['assessmentItemID']+1, self.args.hidden_dim)
        self.embedding_tag = nn.Embedding(self.args.n_cols['KnowledgeTag']+1, self.args.hidden_dim)
        self.embedding_time_diff = nn.Embedding(self.args.n_cols['time_diff']+1, self.args.hidden_dim)
        self.embedding_head = nn.Embedding(self.args.n_cols['head']+1, self.args.hidden_dim)
        self.embedding_mid = nn.Embedding(self.args.n_cols['mid']+1, self.args.hidden_dim)
        self.embedding_tail = nn.Embedding(self.args.n_cols['tail']+1, self.args.hidden_dim)
        self.embedding_mid_tail = nn.Embedding(self.args.n_cols['mid_tail']+1, self.args.hidden_dim)


        # embedding projection
        self.cate_proj = nn.Sequential(
            nn.Linear((self.args.hidden_dim) * (cate_size), self.args.hidden_dim),
            nn.LayerNorm(self.args.hidden_dim),
        )

        if self.args.numeric:
            self.cont_bn = nn.BatchNorm1d(cont_size)
            self.cont_proj = nn.Sequential(
                nn.Linear(cont_size, self.args.hidden_dim),
                nn.LayerNorm(self.args.hidden_dim),
            )

            self.comb_proj = nn.Sequential(
                nn.ReLU(),
                nn.Linear(self.args.hidden_dim * 2, self.args.hidden_dim),
                nn.LayerNorm(self.args.hidden_dim),
            )

        else:
            self.comb_proj = nn.Sequential(
                nn.ReLU(),
                nn.Linear(self.args.hidden_dim, self.args.hidden_dim),
                nn.LayerNorm(self.args.hidden_dim),
            )

        # Bert config
        self.config = BertConfig( 
            3, # not used
            hidden_size=self.args.hidden_dim,
            num_hidden_layers=self.args.n_layers,
            num_attention_heads=self.args.n_heads,
            intermediate_size=self.args.hidden_dim,
            hidden_drop_out_prob=self.args.drop_out,
            attention_probs_drop_out_prob=self.args.drop_out,
            max_position_embeddings=self.args.max_seq_len           
        )

        # Defining the layers
        # Bert Layer
        self.encoder = BertModel(self.config)  

        # Fully connected layer
        self.fc = nn.Linear(self.args.hidden_dim, 1)
       
        self.activation = nn.Sigmoid()

        def get_reg():
            return nn.Sequential(
            nn.Linear(self.args.hidden_dim, self.args.hidden_dim),
            nn.LayerNorm(self.args.hidden_dim),
            nn.Dropout(self.args.drop_out),
            nn.ReLU(),            
            nn.Linear(self.args.hidden_dim, self.args.hidden_dim),
        )     

        self.reg_layer = get_reg()


    def forward(self, inputs):
        #2 process_batch의 return 
        # tail_prob
        (test, question, tag, time_diff, 
        head, mid, tail, mid_tail, 
        head_answerProb, mid_answerProb, tail_answerProb,
        mask, interaction, gather_index, correct) = inputs

        batch_size = interaction.size(0)

        #3 신나는 embedding
        embed_interaction = self.embedding_interaction(interaction)
        embed_test = self.embedding_test(test)
        embed_question = self.embedding_question(question)
        embed_tag = self.embedding_tag(tag)
        embed_time_diff = self.embedding_time_diff(time_diff)
        embed_head = self.embedding_head(head)
        embed_mid = self.embedding_mid(mid)
        embed_tail = self.embedding_tail(tail)
        embed_mid_tail = self.embedding_mid_tail(mid_tail)

        #4
        # (batch_size, max_seq_len, hidden_dim * n) : (64, 20, 64 * n) 
        cate_embed = torch.cat([
                    embed_interaction,
                    embed_question,
                    embed_time_diff,
                    embed_tag,
                    embed_head,
                    embed_mid,
                    embed_tail,
                    embed_test,
                    embed_mid_tail,
                ], 2)

        #5
        # (batch_size, max_seq_len * n) : (64, 20 * n) 
        if self.args.numeric:
            cont_cat = torch.cat([
                    # time_diff,  
                    # head_answerProb,   
                    # mid_answerProb,
                    tail_answerProb,
            ], 1)
            
            # (batch_size, max_seq_len, n) : (64, 20, n) 
            cont_cat = cont_cat.view(batch_size, self.args.max_seq_len, -1)

            # (batch_size * max_seq_len, n) : (1280, 1)
            cont_bn_x = self.cont_bn(cont_cat.view(-1, cont_cat.size(-1)))

            # (batch_size, max_seq_len, n) : (64, 20, n) 
            cont_bn_x = cont_bn_x.view(batch_size, self.args.max_seq_len, -1) 

        # (batch_size, max_seq_len, hidden_dim) : (64, 20, 64)
        cate_X = self.cate_proj(cate_embed)

        if self.args.numeric:
            cont_X = self.cont_proj(cont_cat)

            # (batch_size, max_seq_len, hidden_dim * 2) : [64, 20, 128]
            X = torch.cat([cate_X, cont_X], 2)
            

        else:
            X = cate_X

        # (batch_size, max_seq_len, hidden_dim) :[64, 20, 64]
        comb_X = self.comb_proj(X)

        # Bert
        encoded_layers = self.encoder(inputs_embeds=comb_X, attention_mask=mask)
        out = encoded_layers[0]
        
        
        # base
        # out = out.contiguous().view(batch_size, -1, self.args.hidden_dim)
        # out = self.fc(out)
        # preds = self.activation(out).view(batch_size, -1)

        # reg_layer
        out = self.reg_layer(out)
        out = self.fc(out)
        preds = self.activation(out).view(batch_size, -1)

        return preds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-461acbf0894c> in <module>
#     126         return loss
#     127
# --> 128 class Bert(nn.Module):
#     129     def __init__(self, args):
#     130         super(Bert, self).__init__()
#
# NameError: name 'nn' is not defined

# %%
class Preprocess:
    def __init__(self, args):
        self.args = args

        self.args.cate_cols = []
        self.args.cont_cols = []
        self.args.features = []
        self.args.n_cols = {}

        self.train_data = None
        self.test_data = None


    def get_train_data(self):
        return self.train_data

    def get_test_data(self):
        return self.test_data

    def split_data(self, data, ratio=0.8, shuffle=True, seed=42):
        """
        split data into two parts with a given ratio.
        """
        if shuffle:
            random.seed(seed) # fix to default seed 42
            random.shuffle(data)

        size = int(len(data) * ratio)

        data_1 = data[:size]
        data_2 = data[size:]

        return data_1, data_2

    def __save_labels(self, encoder, name):
        le_path = os.path.join(self.args.asset_dir, name + '_classes.npy')
        np.save(le_path, encoder.classes_)

    def __feature_engineering(self, df):
        #1-1 categorical feature

        df['head'] = df.assessmentItemID.apply(lambda x: x[:4])
        df['mid'] = df.assessmentItemID.apply(lambda x: x[4:7])
        df['tail'] = df.assessmentItemID.apply(lambda x: x[7:])

        df['head_tail'] = df.assessmentItemID.apply(lambda x: x[:4]+x[7:])
        df['mid_tail'] = df.assessmentItemID.apply(lambda x: x[4:])

        #1-2 continuous feature

        def percentile(s):
            return np.sum(s) / len(s)

        ## time to sec
        def convert_time(s):
            timestamp = time.mktime(datetime.strptime(s, '%Y-%m-%d %H:%M:%S').timetuple())
            return int(timestamp)

        df['Timestamp'] = df['Timestamp'].apply(convert_time)

        ## find boundary
        # userID, testId 별 푼 문항의 누적 합
        df['UserTestCumtestnum'] = df.groupby(['userID','testId'])['answerCode'].cumcount()
        testId2maxlen = df[['assessmentItemID', 'testId']].drop_duplicates().groupby('testId').size()
        
        # test의 문항 수
        df['TestSize'] = df.testId.map(testId2maxlen)
        
        # user가 같은 test를 여러 번 푼 것인지 나타낸 변수 (처음 품 : 0, 두번 품 : 1, 세번 품 : 2)
        df['Retest'] = df['UserTestCumtestnum'] // df['TestSize']

        # boundary
        df['boundary'] = [u % t if t != 0 else 0.0 for t, u in zip(df['TestSize'], df['UserTestCumtestnum'])] 

        df = copy.deepcopy(df[df['Retest'] == 0])

        ## time diff
        time_diff = df.groupby(['userID', 'head', 'mid'])['Timestamp'].diff()
        df['time_diff'] = time_diff
        df.loc[df['boundary'] == 0, 'time_diff'] = np.NaN
        df['time_diff'].fillna(method='bfill', inplace=True)
        # df['time_diff'].fillna(0, inplace=True) -> 성능하락

        df['time_diff'] = df['time_diff'].map(lambda x: 600 if x>600 else x)

        # def cate_diff(x):
        #     if x > 600:
        #         return "A"
        #     if 500 < x <= 600:
        #         return "B"
        #     if 400 < x <= 500:
        #         return "C"
        #     if 300 < x <= 400:
        #         return "D"
        #     if 200 < x <= 300:
        #         return "E"
        #     if 100 < x <= 200:
        #         return "F"
        #     if 50 < x <= 100:
        #         return "G"
        #     if x <= 50:
        #         return "H"

        # load
        # with open('/opt/ml/code/dkt/max_bins_set.pkl', 'rb') as f:
        #     ser, bins = pickle.load(f)

        # df['time_diff'] = df['time_diff'].map(lambda x: cate_diff(x))
        # df['time_diff'] = pd.qcut(df['time_diff'], q=23).cat.rename_categories(list(range(23))).astype(str)
        # df['time_diff'] = pd.qcut(df['time_diff'], q=20).cat.rename_categories(list('abcdefghijklnmopqrst')).astype(str)
        # df['time_diff'] = pd.qcut(df['time_diff'], q=20).astype(str)

        # df['time_diff'] = pd.cut(df['time_diff'], bins=bins, labels=False, include_lowest=True)
        
        thr = 600
        df['time_diff'] = pd.cut(df['time_diff'], bins=thr).astype(str) #.cat.rename_categories(list(range(thr)))
        # df['time_diff'] = pd.cut(df['time_diff'], bins=600).astype(str)

        # head별 정답률
        answer_head_mean = df.groupby(['userID', 'head'])['answerCode'].mean()
        answer_head_mean = answer_head_mean.reset_index(level=['userID', 'head'])
        answer_head_mean.columns = ['userID', 'head', 'head_answerProb']

        df = pd.merge(df, answer_head_mean, on=['userID', 'head'], how='left')

        # mid별 정답률
        answer_mid_mean = df.groupby(['userID', 'head', 'mid'])['answerCode'].mean()
        answer_mid_mean = answer_mid_mean.reset_index(level=['userID', 'head', 'mid'])
        answer_mid_mean.columns = ['userID', 'head', 'mid', 'mid_answerProb']

        df = pd.merge(df, answer_mid_mean, on=['userID', 'head', 'mid'], how='left')
        
        # tail별 정답률
        answer_tail_mean = df.groupby(['head', 'mid', 'tail'])['answerCode'].mean()
        answer_tail_mean = answer_tail_mean.reset_index(level=['head', 'mid', 'tail'])
        answer_tail_mean.columns = ['head', 'mid', 'tail', 'tail_answerProb']

        df = pd.merge(df, answer_tail_mean, on=['head', 'mid', 'tail'], how='left')

        #2 self.args.features의 순서와 trainer #1의 순서를 맞춰주자!
        # correct, question, test, tag, time_diff, head, mid, tail, mid_tail, 
        # head_answerProb, mid_answerProb, tail_answerProb, mask = batch

        self.args.cate_cols.extend([
            'assessmentItemID', 
            'testId', 
            'KnowledgeTag',
            'time_diff',
            'head',
            'mid',
            'tail',
            'mid_tail',
            ])

        self.args.cont_cols.extend([
            # 'time_diff',
            # 'time_median',
            'head_answerProb',
            'mid_answerProb',
            'tail_answerProb',
            ])

        self.args.features.extend(
            ['answerCode'] + 
            self.args.cate_cols + 
            self.args.cont_cols
            )

        return df

    def __preprocessing(self, df, is_train = True):
        cate_cols = self.args.cate_cols

        if not os.path.exists(self.args.asset_dir):
            os.makedirs(self.args.asset_dir)
            
        for col in cate_cols:
            le = LabelEncoder()
            if is_train:
                #For UNKNOWN class
                a = df[col].unique().tolist() + ['unknown']
                le.fit(a)
                self.__save_labels(le, col)
            else:
                label_path = os.path.join(self.args.asset_dir,col+'_classes.npy')
                le.classes_ = np.load(label_path)
                
                df[col] = df[col].apply(lambda x: x if x in le.classes_ else 'unknown')

            #모든 컬럼이 범주형이라고 가정
            df[col]= df[col].astype(str)
            test = le.transform(df[col])
            df[col] = test


        cont_cols = self.args.cont_cols

        # standard scaler
        std_scaler = preprocessing.StandardScaler().fit(df[cont_cols] )
        df[cont_cols] = std_scaler.transform(df[cont_cols])
        

        # df.to_csv('peprocess_test.csv')

        return df


    def load_data_from_file(self, file_name, is_train=True):
        csv_file_path = os.path.join(self.args.data_dir, file_name)
        df = pd.read_csv(csv_file_path)
        df = self.__feature_engineering(df)
        df = self.__preprocessing(df, is_train)
        
        cols = df.columns.tolist()
        for col in cols:
            if col in self.args.cont_cols:
                self.args.n_cols[col] = len(df[col].unique())
            
            if col in self.args.cate_cols:
                self.args.n_cols[col] = len(np.load(os.path.join(self.args.asset_dir, f'{col}_classes.npy')))

        df = df.sort_values(by=['userID','Timestamp'], axis=0)

        feature_columns = self.args.features        
        
        def get_values(cols, r):
            result = []
            for col in cols:
                result.append(r[col].values)

            return result

        if is_train:
            group = df.groupby(['userID', 'head', 'mid']).apply(
                lambda r: (get_values(feature_columns, r)))
            
        else:
            group = df.groupby('userID').apply(
                lambda r: (get_values(feature_columns, r)))

        if is_train:
            # save
            mass = (self.args.cate_cols, self.args.cont_cols, self.args.features)
            with open('../dkt/code/dkt/pkl/mass.pkl', 'wb') as f:
                pickle.dump(mass, f, pickle.HIGHEST_PROTOCOL)

            save_name = f'{self.args.pkl_dir}/{self.args.pkl_name}'
            with open(save_name, 'wb') as f:
                pickle.dump((group.values, self.args.n_cols), f, pickle.HIGHEST_PROTOCOL)

        return group.values

    def load_train_data(self, file_name):
        if self.args.pkl:
            # load
            pkl_name = f'{self.args.pkl_dir}/{self.args.pkl_name}'
            with open(pkl_name, 'rb') as f:
                self.train_data, self.args.n_cols = pickle.load(f)
            
            with open('../dkt/code/dkt/pkl/mass.pkl', 'rb') as f:
                self.args.cate_cols, self.args.cont_cols, self.args.features = pickle.load(f)
        else:
            self.train_data = self.load_data_from_file(file_name)

    def load_test_data(self, file_name):
        self.test_data = self.load_data_from_file(file_name, is_train= False)

# %%
class Bert(nn.Module):
    
    def __init__(self, args):
        super(Bert, self).__init__()
        self.args = args
        self.args.numeric = False
        
        cate_size = len(self.args.cate_cols) + 1 # interaction
        cont_size = len(self.args.cont_cols) - 2


        #1 Embedding 
        # interaction은 현재 correct으로 구성되어있다. correct(1, 2) + padding(0)
        self.embedding_interaction = nn.Embedding(3, self.args.hidden_dim)
        self.embedding_test = nn.Embedding(self.args.n_cols['testId']+1, self.args.hidden_dim)
        self.embedding_question = nn.Embedding(self.args.n_cols['assessmentItemID']+1, self.args.hidden_dim)
        self.embedding_tag = nn.Embedding(self.args.n_cols['KnowledgeTag']+1, self.args.hidden_dim)
        self.embedding_time_diff = nn.Embedding(self.args.n_cols['time_diff']+1, self.args.hidden_dim)
        self.embedding_head = nn.Embedding(self.args.n_cols['head']+1, self.args.hidden_dim)
        self.embedding_mid = nn.Embedding(self.args.n_cols['mid']+1, self.args.hidden_dim)
        self.embedding_tail = nn.Embedding(self.args.n_cols['tail']+1, self.args.hidden_dim)
        self.embedding_mid_tail = nn.Embedding(self.args.n_cols['mid_tail']+1, self.args.hidden_dim)


        # embedding projection
        self.cate_proj = nn.Sequential(
            nn.Linear((self.args.hidden_dim) * (cate_size), self.args.hidden_dim),
            nn.LayerNorm(self.args.hidden_dim),
        )

        if self.args.numeric:
            self.cont_bn = nn.BatchNorm1d(cont_size)
            self.cont_proj = nn.Sequential(
                nn.Linear(cont_size, self.args.hidden_dim),
                nn.LayerNorm(self.args.hidden_dim),
            )

            self.comb_proj = nn.Sequential(
                nn.ReLU(),
                nn.Linear(self.args.hidden_dim * 2, self.args.hidden_dim),
                nn.LayerNorm(self.args.hidden_dim),
            )

        else:
            self.comb_proj = nn.Sequential(
                nn.ReLU(),
                nn.Linear(self.args.hidden_dim, self.args.hidden_dim),
                nn.LayerNorm(self.args.hidden_dim),
            )

        # Bert config
        self.config = BertConfig( 
            3, # not used
            hidden_size=self.args.hidden_dim,
            num_hidden_layers=self.args.n_layers,
            num_attention_heads=self.args.n_heads,
            intermediate_size=self.args.hidden_dim,
            hidden_drop_out_prob=self.args.drop_out,
            attention_probs_drop_out_prob=self.args.drop_out,
            max_position_embeddings=self.args.max_seq_len           
        )

        # Defining the layers
        # Bert Layer
        self.encoder = BertModel(self.config)  

        # Fully connected layer
        self.fc = nn.Linear(self.args.hidden_dim, 1)
       
        self.activation = nn.Sigmoid()

        def get_reg():
            return nn.Sequential(
            nn.Linear(self.args.hidden_dim, self.args.hidden_dim),
            nn.LayerNorm(self.args.hidden_dim),
            nn.Dropout(self.args.drop_out),
            nn.ReLU(),            
            nn.Linear(self.args.hidden_dim, self.args.hidden_dim),
        )     

        self.reg_layer = get_reg()


    def forward(self, inputs):
        #2 process_batch의 return 
        # tail_prob
        (test, question, tag, time_diff, 
        head, mid, tail, mid_tail, 
        head_answerProb, mid_answerProb, tail_answerProb,
        mask, interaction, gather_index, correct) = inputs

        batch_size = interaction.size(0)

        #3 신나는 embedding
        embed_interaction = self.embedding_interaction(interaction)
        embed_test = self.embedding_test(test)
        embed_question = self.embedding_question(question)
        embed_tag = self.embedding_tag(tag)
        embed_time_diff = self.embedding_time_diff(time_diff)
        embed_head = self.embedding_head(head)
        embed_mid = self.embedding_mid(mid)
        embed_tail = self.embedding_tail(tail)
        embed_mid_tail = self.embedding_mid_tail(mid_tail)

        #4
        # (batch_size, max_seq_len, hidden_dim * n) : (64, 20, 64 * n) 
        cate_embed = torch.cat([
                    embed_interaction,
                    embed_question,
                    embed_time_diff,
                    embed_tag,
                    embed_head,
                    embed_mid,
                    embed_tail,
                    embed_test,
                    embed_mid_tail,
                ], 2)

        #5
        # (batch_size, max_seq_len * n) : (64, 20 * n) 
        if self.args.numeric:
            cont_cat = torch.cat([
                    # time_diff,  
                    # head_answerProb,   
                    # mid_answerProb,
                    tail_answerProb,
            ], 1)
            
            # (batch_size, max_seq_len, n) : (64, 20, n) 
            cont_cat = cont_cat.view(batch_size, self.args.max_seq_len, -1)

            # (batch_size * max_seq_len, n) : (1280, 1)
            cont_bn_x = self.cont_bn(cont_cat.view(-1, cont_cat.size(-1)))

            # (batch_size, max_seq_len, n) : (64, 20, n) 
            cont_bn_x = cont_bn_x.view(batch_size, self.args.max_seq_len, -1) 

        # (batch_size, max_seq_len, hidden_dim) : (64, 20, 64)
        cate_X = self.cate_proj(cate_embed)

        if self.args.numeric:
            cont_X = self.cont_proj(cont_cat)

            # (batch_size, max_seq_len, hidden_dim * 2) : [64, 20, 128]
            X = torch.cat([cate_X, cont_X], 2)
            

        else:
            X = cate_X

        # (batch_size, max_seq_len, hidden_dim) :[64, 20, 64]
        comb_X = self.comb_proj(X)

        # Bert
        encoded_layers = self.encoder(inputs_embeds=comb_X, attention_mask=mask)
        out = encoded_layers[0]
        
        
        # base
        # out = out.contiguous().view(batch_size, -1, self.args.hidden_dim)
        # out = self.fc(out)
        # preds = self.activation(out).view(batch_size, -1)

        # reg_layer
        out = self.reg_layer(out)
        out = self.fc(out)
        preds = self.activation(out).view(batch_size, -1)

        return preds

# %%
args.pkl_dir = "/home/j-gunmo/desktop/00.my-project/17.P-Stage-T1003/4-STAGE/dkt/code/dkt/pkl"
args.pkl_name = 'group.pkl'
args.pkl = True

# %%
import os
import copy
import time
import random
import pickle

import pandas as pd
import numpy as np

from datetime import datetime

from sklearn.preprocessing import LabelEncoder
from sklearn import preprocessing

from torch.nn.utils.rnn import pad_sequence
import torch

# %%
from dkt.code.args import parse_args

# %%
import argparse

# %%
def parse_args(mode='train'):
    parser = argparse.ArgumentParser()

    
    parser.add_argument('--seed', default=42, type=int, help='seed')
    
    parser.add_argument('--device', default='cpu', type=str, help='cpu or gpu')

    parser.add_argument('--data_dir', default='/opt/ml/dkt/dkt/input/data/train_dataset', type=str, help='data directory')
    parser.add_argument('--asset_dir', default='asset/', type=str, help='data directory')
    
    parser.add_argument('--file_name', default='train_data.csv', type=str, help='train file name')
    
    parser.add_argument('--pkl', default=True, type=str2bool, help='use pkl')
    parser.add_argument('--pkl_dir', default='/opt/ml/dkt/dkt/code/dkt/pkl', type=str, help='pkl directory')
    parser.add_argument('--pkl_name', default='group.pkl', type=str, help='pkl file name')
    
    parser.add_argument('--model_dir', default='/opt/ml/dkt/dkt/code/models/', type=str, help='model directory')
    parser.add_argument('--model_name', default='model.pt', type=str, help='model file name')

    parser.add_argument('--output_dir', default='/opt/ml/dkt/dkt/code/output/', type=str, help='output directory')
    parser.add_argument('--test_file_name', default='test_data.csv', type=str, help='test file name')
    
    parser.add_argument('--max_seq_len', default=13, type=int, help='max sequence length')
    parser.add_argument('--num_workers', default=4, type=int, help='number of workers')

    # 모델
    parser.add_argument('--hidden_dim', default=1024, type=int, help='hidden dimension size')
    parser.add_argument('--n_layers', default=2, type=int, help='number of layers')
    parser.add_argument('--n_heads', default=2, type=int, help='number of heads')
    parser.add_argument('--drop_out', default=0, type=float, help='drop out rate')
    
    # 훈련
    parser.add_argument('--n_epochs', default=20, type=int, help='number of epochs')
    parser.add_argument('--batch_size', default=64, type=int, help='batch size')
    parser.add_argument('--lr', default=0.0001, type=float, help='learning rate')
    parser.add_argument('--clip_grad', default=10, type=int, help='clip grad')
    parser.add_argument('--patience', default=10, type=int, help='for early stopping')
    

    parser.add_argument('--log_steps', default=100, type=int, help='print log per n steps')

    ### 중요 ###
    parser.add_argument('--model', default='bert', type=str, help='model type')
    parser.add_argument('--optimizer', default='adam', type=str, help='optimizer type')
    parser.add_argument('--scheduler', default='plateau', type=str, help='scheduler type')


    parser.add_argument('--info', default='test', type=str, help='file info')
    
    args = parser.parse_args([])

    return args

# %%
args = parse_args()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-8df83216b7d4> in <module>
# ----> 1 args = parse_args()
#
# <ipython-input-28-7f55f1c1f799> in parse_args(mode)
#      12     parser.add_argument('--file_name', default='train_data.csv', type=str, help='train file name')
#      13
# ---> 14     parser.add_argument('--pkl', default=True, type=str2bool, help='use pkl')
#      15     parser.add_argument('--pkl_dir', default='/opt/ml/dkt/dkt/code/dkt/pkl', type=str, help='pkl directory')
#      16     parser.add_argument('--pkl_name', default='group.pkl', type=str, help='pkl file name')
#
# NameError: name 'str2bool' is not defined

# %%
preprocess = Preprocess(args)

# %%
train_dataset = preprocess.load_train_data("train_data.csv")
test_dataset = preprocess.load_test_data("test_data.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-42c184feda76> in <module>
#       1 train_dataset = preprocess.load_train_data("train_data.csv")
# ----> 2 test_dataset = preprocess.load_test_data("test_data.csv")
#
# <ipython-input-3-43f94a4e5d02> in load_test_data(self, file_name)
#     264
#     265     def load_test_data(self, file_name):
# --> 266         self.test_data = self.load_data_from_file(file_name, is_train= False)
#
# <ipython-input-3-43f94a4e5d02> in load_data_from_file(self, file_name, is_train)
#     210         df = pd.read_csv(csv_file_path)
#     211         df = self.__feature_engineering(df)
# --> 212         df = self.__preprocessing(df, is_train)
#     213
#     214         cols = df.columns.tolist()
#
# <ipython-input-3-43f94a4e5d02> in __preprocessing(self, df, is_train)
#     172         cate_cols = self.args.cate_cols
#     173
# --> 174         if not os.path.exists(self.args.asset_dir):
#     175             os.makedirs(self.args.asset_dir)
#     176
#
# AttributeError: 'EasyDict' object has no attribute 'asset_dir'

# %%
preprocess.load_train_data??
# Out:
# Signature: preprocess.load_train_data(file_name)
# Docstring: <no docstring>
# Source:
#     def load_train_data(self, file_name):
#         if self.args.pkl:
#             # load
#             pkl_name = f'{self.args.pkl_dir}/{self.args.pkl_name}'
#             with open(pkl_name, 'rb') as f:
#                 self.train_data, self.args.n_cols = pickle.load(f)
#
#             with open('../dkt/code/dkt/pkl/mass.pkl', 'rb') as f:
#                 self.args.cate_cols, self.args.cont_cols, self.args.features = pickle.load(f)
#         else:
#             self.train_data = self.load_data_from_file(file_name)
# File:      ~/desktop/00.my-project/17.P-Stage-T1003/4-STAGE/notebook/<ipython-input-3-43f94a4e5d02>
# Type:      method

# %%
from glob import glob

# %%
all_csv_file = []

folders = ['feature_test', 'hyper_test', 'split_test', 'refactoring']

# %%
for file_path in glob('../feature_test/*/*.csv'):
    folder_path = "/".join(file_path.split("/")[:-1])
    print(os.listdir(folder_path))
    break
    print(folder_path)
# Out:
# ['run_config.json', 'cv_0.log', 'cv_1.log', 'cv_0_model.pth', 'cv_1_model.pth', 'cv_0_test_results.csv']

# %%
from shutil import copy2

# %%
copy2??
# Out:
# Signature: copy2(src, dst, *, follow_symlinks=True)
# Source:
# def copy2(src, dst, *, follow_symlinks=True):
#     """Copy data and metadata. Return the file's destination.
#
#     Metadata is copied with copystat(). Please see the copystat function
#     for more information.
#
#     The destination may be a directory.
#
#     If follow_symlinks is false, symlinks won't be followed. This
#     resembles GNU's "cp -P src dst".
#     """
#     if os.path.isdir(dst):
#         dst = os.path.join(dst, os.path.basename(src))
#     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     copystat(src, dst, follow_symlinks=follow_symlinks)
#     return dst
# File:      ~/anaconda3/envs/baseline_code/lib/python3.8/shutil.py
# Type:      function

# %%
copy??
# Out:
# Signature: copy(src, dst, *, follow_symlinks=True)
# Source:
# def copy(src, dst, *, follow_symlinks=True):
#     """Copy data and mode bits ("cp src dst"). Return the file's destination.
#
#     The destination may be a directory.
#
#     If follow_symlinks is false, symlinks won't be followed. This
#     resembles GNU's "cp -P src dst".
#
#     If source and destination are the same file, a SameFileError will be
#     raised.
#
#     """
#     if os.path.isdir(dst):
#         dst = os.path.join(dst, os.path.basename(src))
#     copyfile(src, dst, follow_symlinks=follow_symlinks)
#     copymode(src, dst, follow_symlinks=follow_symlinks)
#     return dst
# File:      ~/anaconda3/envs/baseline_code/lib/python3.8/shutil.py
# Type:      function

# %%
count = 0

# %%
count
# Out:
# -77

# %%
import json

for folder in folders:
    for file_path in glob(f"../{folder}/*/*.csv"):
        log_folder_path = "/".join(file_path.split("/")[:-1])
        file_name = file_path.split("/")[-1]
        
        if "valid_cv_results.json" not in os.listdir(log_folder_path):
            continue
            
        valid_cv_result = json.load(open(f"{log_folder_path}/valid_cv_results.json", 'r'))
        
        if "ensemble" in file_name:
            auc, acc = 0, 0
            
            for i, (k, v) in enumerate(valid_cv_result.items()):
                auc += float(v.split(",")[0].split(":")[1])
                acc += float(v.split(",")[1].split(":")[1])
        
            auc /= (i + 1)
            acc /= (i + 1)  
        else:
            for k, v in valid_cv_result.items():
                if k in file_name:
                    auc = float(v.split(",")[0].split(":")[1])
                    acc = float(v.split(",")[1].split(":")[1])
        
        print(file_name)
        model_name = "bert" if "bert" in folder_path else "lstm"
        new_file_name = f"../all_csvs/{model_name}_{auc*100:.4}_{acc*100:.4}_{file_name}"
        
        line_num = [line for line in open(file_path, "r")]
        
        if len(line_num) != 745:
            count += 1
            continue
        count -= 1
        
        print(len(line_num))
        
        
        print(new_file_name)
        copy(file_path, new_file_name)
        print(f"file_path: {file_path}\nauc: {auc}\nacc: {acc}")
        print()
# Out:
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_79.59_72.22_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.11_15:05]/cv_ensemble_test_results.csv
# auc: 0.7958974961259273
# acc: 0.7222391084093213
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_79.71_72.59_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.11_15:05]/cv_3_test_results.csv
# auc: 0.7970689652959844
# acc: 0.7259371833839919
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_80.09_72.67_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.11_15:05]/cv_1_test_results.csv
# auc: 0.8009134775801442
# acc: 0.7266970618034447
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_79.8_72.29_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.11_15:05]/cv_0_test_results.csv
# auc: 0.7979912366365132
# acc: 0.7228976697061803
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_78.89_71.35_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.11_15:05]/cv_2_test_results.csv
# auc: 0.7888690074378204
# acc: 0.7135258358662614
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_79.46_72.21_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.11_15:05]/cv_4_test_results.csv
# auc: 0.7946447936791747
# acc: 0.7221377912867275
#
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_78.1_70.35_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.10_09:57]/cv_ensemble_test_results.csv
# auc: 0.7810246989556201
# acc: 0.7034954407294831
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_77.22_70.24_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.10_09:57]/cv_3_test_results.csv
# auc: 0.7721980538755782
# acc: 0.7023809523809523
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_78.48_71.2_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.10_09:57]/cv_1_test_results.csv
# auc: 0.7848139927395775
# acc: 0.7120060790273556
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_78.48_69.28_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.10_09:57]/cv_0_test_results.csv
# auc: 0.7848431941602013
# acc: 0.6927558257345492
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_77.96_70.34_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.10_09:57]/cv_2_test_results.csv
# auc: 0.7796181404957299
# acc: 0.7033941236068896
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_78.37_70.69_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.10_09:57]/cv_4_test_results.csv
# auc: 0.7836501135070137
# acc: 0.7069402228976697
#
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.6_70.14_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:46]/cv_ensemble_test_results.csv
# auc: 0.7660024559671778
# acc: 0.701418439716312
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_75.86_69.66_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:46]/cv_3_test_results.csv
# auc: 0.7586366297566433
# acc: 0.6965552178318136
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.65_70.49_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:46]/cv_1_test_results.csv
# auc: 0.7664909737507802
# acc: 0.7049138804457954
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_77.06_69.98_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:46]/cv_0_test_results.csv
# auc: 0.770580164263608
# acc: 0.6998480243161094
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_76.77_70.26_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:46]/cv_2_test_results.csv
# auc: 0.7677161260973782
# acc: 0.7026342451874367
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_76.66_70.31_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:46]/cv_4_test_results.csv
# auc: 0.7665883859674789
# acc: 0.7031408308004052
#
# cv_ensemble_test_results.csv
# cv_3_test_results.csv
# cv_1_test_results.csv
# cv_0_test_results.csv
# cv_2_test_results.csv
# cv_4_test_results.csv
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.05_69.7_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:07]/cv_ensemble_test_results.csv
# auc: 0.7605497004766788
# acc: 0.6969604863221884
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_75.07_69.28_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:07]/cv_3_test_results.csv
# auc: 0.7506701015977459
# acc: 0.6927558257345492
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.39_69.6_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:07]/cv_1_test_results.csv
# auc: 0.7639374548276883
# acc: 0.6960486322188449
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_76.9_70.34_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:07]/cv_0_test_results.csv
# auc: 0.7689946979828697
# acc: 0.7033941236068896
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_75.89_69.58_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:07]/cv_2_test_results.csv
# auc: 0.7589240077868059
# acc: 0.6957953394123607
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_76.02_69.68_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:07]/cv_4_test_results.csv
# auc: 0.7602222401882843
# acc: 0.6968085106382979
#
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.63_70.19_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:01]/cv_ensemble_test_results.csv
# auc: 0.7662840384422888
# acc: 0.7018743667679839
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_75.88_69.6_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:01]/cv_3_test_results.csv
# auc: 0.7587724082667295
# acc: 0.6960486322188449
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.63_70.21_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:01]/cv_1_test_results.csv
# auc: 0.7663265824682152
# acc: 0.7021276595744681
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_77.02_69.78_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:01]/cv_0_test_results.csv
# auc: 0.7702280239933297
# acc: 0.6978216818642351
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_76.83_70.47_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:01]/cv_2_test_results.csv
# auc: 0.7683204430356836
# acc: 0.704660587639311
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_76.78_70.87_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:01]/cv_4_test_results.csv
# auc: 0.767772734447486
# acc: 0.7087132725430598
#
# cv_ensemble_test_results.csv
# cv_3_test_results.csv
# cv_1_test_results.csv
# cv_0_test_results.csv
# cv_2_test_results.csv
# cv_4_test_results.csv
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_78.84_69.69_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.11_15:31]/cv_ensemble_test_results.csv
# auc: 0.7884153577405428
# acc: 0.6969098277608916
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_79.02_69.53_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.11_15:31]/cv_3_test_results.csv
# auc: 0.7902152975885695
# acc: 0.6952887537993921
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_79.4_70.09_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.11_15:31]/cv_1_test_results.csv
# auc: 0.7940499473832807
# acc: 0.7008611955420466
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_79.12_69.73_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.11_15:31]/cv_0_test_results.csv
# auc: 0.791214021381579
# acc: 0.6973150962512664
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_77.84_69.05_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.11_15:31]/cv_2_test_results.csv
# auc: 0.7784456301392524
# acc: 0.6904761904761905
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_78.82_70.06_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.11_15:31]/cv_4_test_results.csv
# auc: 0.7881518922100326
# acc: 0.7006079027355623
#
# cv_ensemble_test_results.csv
# cv_3_test_results.csv
# cv_1_test_results.csv
# cv_0_test_results.csv
# cv_2_test_results.csv
# cv_4_test_results.csv
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.03_69.73_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:38]/cv_ensemble_test_results.csv
# auc: 0.7602511271319058
# acc: 0.6972644376899696
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_74.9_69.33_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:38]/cv_3_test_results.csv
# auc: 0.7490099590585442
# acc: 0.6932624113475178
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.33_69.66_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:38]/cv_1_test_results.csv
# auc: 0.7633242920266764
# acc: 0.6965552178318136
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_77.01_70.59_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:38]/cv_0_test_results.csv
# auc: 0.770105976106878
# acc: 0.7059270516717325
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_75.89_69.55_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:38]/cv_2_test_results.csv
# auc: 0.7588933298453755
# acc: 0.6955420466058764
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_75.99_69.5_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:38]/cv_4_test_results.csv
# auc: 0.7599220786220544
# acc: 0.6950354609929078
#
# cv_ensemble_test_results.csv
# cv_3_test_results.csv
# cv_1_test_results.csv
# cv_0_test_results.csv
# cv_2_test_results.csv
# cv_4_test_results.csv
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.04_69.74_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:22]/cv_ensemble_test_results.csv
# auc: 0.7604093062319465
# acc: 0.6973657548125634
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_74.99_69.17_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:22]/cv_3_test_results.csv
# auc: 0.7498676223694196
# acc: 0.6917426545086119
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.36_69.96_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:22]/cv_1_test_results.csv
# auc: 0.7635709431157396
# acc: 0.6995947315096251
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_77.0_70.36_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:22]/cv_0_test_results.csv
# auc: 0.7699690255311331
# acc: 0.7036474164133738
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_75.88_69.71_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:22]/cv_2_test_results.csv
# auc: 0.7588264545002487
# acc: 0.6970618034447822
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_75.98_69.48_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:22]/cv_4_test_results.csv
# auc: 0.7598124856431915
# acc: 0.6947821681864235
#
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.55_70.1_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:50]/cv_ensemble_test_results.csv
# auc: 0.7655200424923057
# acc: 0.7010131712259371
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_75.77_69.48_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:50]/cv_3_test_results.csv
# auc: 0.7577477810223737
# acc: 0.6947821681864235
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.64_70.36_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:50]/cv_1_test_results.csv
# auc: 0.7664191087092217
# acc: 0.7036474164133738
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_77.06_70.14_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:50]/cv_0_test_results.csv
# auc: 0.7705689872466384
# acc: 0.7013677811550152
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_76.69_70.29_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:50]/cv_2_test_results.csv
# auc: 0.7668902605109175
# acc: 0.702887537993921
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_76.6_70.24_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:50]/cv_4_test_results.csv
# auc: 0.7659740749723771
# acc: 0.7023809523809523
#
# cv_ensemble_test_results.csv
# cv_3_test_results.csv
# cv_1_test_results.csv
# cv_0_test_results.csv
# cv_2_test_results.csv
# cv_4_test_results.csv
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_78.38_69.31_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.10_09:52]/cv_ensemble_test_results.csv
# auc: 0.7838349380100875
# acc: 0.6931104356636272
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_77.35_69.07_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.10_09:52]/cv_3_test_results.csv
# auc: 0.7734571493032304
# acc: 0.6907294832826748
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_78.7_70.16_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.10_09:52]/cv_1_test_results.csv
# auc: 0.787002411585466
# acc: 0.7016210739614995
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_78.89_68.74_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.10_09:52]/cv_0_test_results.csv
# auc: 0.788881052129864
# acc: 0.6874366767983789
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_78.39_69.3_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.10_09:52]/cv_2_test_results.csv
# auc: 0.7839171598028087
# acc: 0.6930091185410334
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_78.59_69.28_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.10_09:52]/cv_4_test_results.csv
# auc: 0.7859169172290685
# acc: 0.6927558257345492
#
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.63_70.19_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:58]/cv_ensemble_test_results.csv
# auc: 0.7662840384422888
# acc: 0.7018743667679839
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_75.88_69.6_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:58]/cv_3_test_results.csv
# auc: 0.7587724082667295
# acc: 0.6960486322188449
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.63_70.21_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:58]/cv_1_test_results.csv
# auc: 0.7663265824682152
# acc: 0.7021276595744681
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_77.02_69.78_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:58]/cv_0_test_results.csv
# auc: 0.7702280239933297
# acc: 0.6978216818642351
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_76.83_70.47_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:58]/cv_2_test_results.csv
# auc: 0.7683204430356836
# acc: 0.704660587639311
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_76.78_70.87_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:58]/cv_4_test_results.csv
# auc: 0.767772734447486
# acc: 0.7087132725430598
#
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.05_69.7_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:05]/cv_ensemble_test_results.csv
# auc: 0.7605497004766788
# acc: 0.6969604863221884
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_75.07_69.28_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:05]/cv_3_test_results.csv
# auc: 0.7506701015977459
# acc: 0.6927558257345492
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.39_69.6_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:05]/cv_1_test_results.csv
# auc: 0.7639374548276883
# acc: 0.6960486322188449
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_76.9_70.34_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:05]/cv_0_test_results.csv
# auc: 0.7689946979828697
# acc: 0.7033941236068896
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_75.89_69.58_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:05]/cv_2_test_results.csv
# auc: 0.7589240077868059
# acc: 0.6957953394123607
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_76.02_69.68_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:05]/cv_4_test_results.csv
# auc: 0.7602222401882843
# acc: 0.6968085106382979
#
# cv_ensemble_test_results.csv
# cv_3_test_results.csv
# cv_1_test_results.csv
# cv_0_test_results.csv
# cv_2_test_results.csv
# cv_4_test_results.csv
# cv_ensemble_test_results.csv
# cv_3_test_results.csv
# cv_1_test_results.csv
# cv_0_test_results.csv
# cv_2_test_results.csv
# cv_4_test_results.csv
# cv_ensemble_test_results.csv
# cv_3_test_results.csv
# cv_1_test_results.csv
# cv_0_test_results.csv
# cv_2_test_results.csv
# cv_4_test_results.csv
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.65_70.34_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:31]/cv_ensemble_test_results.csv
# auc: 0.7665131375039842
# acc: 0.7034447821681864
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_75.9_69.78_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:31]/cv_3_test_results.csv
# auc: 0.759020351632974
# acc: 0.6978216818642351
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.68_70.67_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:31]/cv_1_test_results.csv
# auc: 0.7667907536384244
# acc: 0.7066869300911854
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_77.11_70.42_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:31]/cv_0_test_results.csv
# auc: 0.7711385012262602
# acc: 0.7041540020263425
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_76.84_70.47_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:31]/cv_2_test_results.csv
# auc: 0.7684498294999599
# acc: 0.704660587639311
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_76.72_70.39_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:31]/cv_4_test_results.csv
# auc: 0.7671662515223029
# acc: 0.7039007092198581
#
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.3_69.96_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.08_09:04]/cv_ensemble_test_results.csv
# auc: 0.7629540524229372
# acc: 0.699645390070922
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_75.35_69.48_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.08_09:04]/cv_3_test_results.csv
# auc: 0.7535217069797084
# acc: 0.6947821681864235
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.72_70.29_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.08_09:04]/cv_1_test_results.csv
# auc: 0.7672115491228358
# acc: 0.702887537993921
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_77.11_70.44_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.08_09:04]/cv_0_test_results.csv
# auc: 0.771092893858165
# acc: 0.7044072948328267
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_76.09_69.88_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.08_09:04]/cv_2_test_results.csv
# auc: 0.7609405369076173
# acc: 0.6988348530901722
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_76.2_69.73_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.08_09:04]/cv_4_test_results.csv
# auc: 0.7620035752463595
# acc: 0.6973150962512664
#
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.65_70.24_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:28]/cv_ensemble_test_results.csv
# auc: 0.7665253725938547
# acc: 0.7023809523809523
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_75.91_69.68_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:28]/cv_3_test_results.csv
# auc: 0.7590816957991566
# acc: 0.6968085106382979
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.66_70.57_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:28]/cv_1_test_results.csv
# auc: 0.7666470235553073
# acc: 0.7056737588652482
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_77.13_70.14_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:28]/cv_0_test_results.csv
# auc: 0.7713130939396159
# acc: 0.7013677811550152
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_76.86_70.47_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:28]/cv_2_test_results.csv
# auc: 0.7685517470124947
# acc: 0.704660587639311
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_76.7_70.34_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:28]/cv_4_test_results.csv
# auc: 0.7670333026626988
# acc: 0.7033941236068896
#
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.04_69.69_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:17]/cv_ensemble_test_results.csv
# auc: 0.7604321125475101
# acc: 0.6969098277608915
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_75.01_69.22_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:17]/cv_3_test_results.csv
# auc: 0.7500678250875052
# acc: 0.6922492401215805
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.34_70.06_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:17]/cv_1_test_results.csv
# auc: 0.7634482592233648
# acc: 0.7006079027355623
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_76.98_70.31_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:17]/cv_0_test_results.csv
# auc: 0.7697734919698914
# acc: 0.7031408308004052
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_75.89_69.6_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:17]/cv_2_test_results.csv
# auc: 0.7589417214098912
# acc: 0.6960486322188449
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_75.99_69.25_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.08_11:17]/cv_4_test_results.csv
# auc: 0.7599292650468978
# acc: 0.6925025329280649
#
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.59_70.23_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.09_13:53]/cv_ensemble_test_results.csv
# auc: 0.7658911101756501
# acc: 0.7022796352583587
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_75.85_69.58_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.09_13:53]/cv_3_test_results.csv
# auc: 0.7585313949945727
# acc: 0.6957953394123607
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.64_70.69_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.09_13:53]/cv_1_test_results.csv
# auc: 0.7663933142925194
# acc: 0.7069402228976697
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_77.04_70.04_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.09_13:53]/cv_0_test_results.csv
# auc: 0.7703509711799974
# acc: 0.700354609929078
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_76.76_70.44_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.09_13:53]/cv_2_test_results.csv
# auc: 0.7675726200784687
# acc: 0.7044072948328267
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_76.66_70.39_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.09_13:53]/cv_4_test_results.csv
# auc: 0.766607250332693
# acc: 0.7039007092198581
#
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.63_70.19_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:05]/cv_ensemble_test_results.csv
# auc: 0.7662840384422888
# acc: 0.7018743667679839
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_75.88_69.6_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:05]/cv_3_test_results.csv
# auc: 0.7587724082667295
# acc: 0.6960486322188449
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.63_70.21_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:05]/cv_1_test_results.csv
# auc: 0.7663265824682152
# acc: 0.7021276595744681
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_77.02_69.78_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:05]/cv_0_test_results.csv
# auc: 0.7702280239933297
# acc: 0.6978216818642351
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_76.83_70.47_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:05]/cv_2_test_results.csv
# auc: 0.7683204430356836
# acc: 0.704660587639311
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_76.78_70.87_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:05]/cv_4_test_results.csv
# auc: 0.767772734447486
# acc: 0.7087132725430598
#
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.04_69.69_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:15]/cv_ensemble_test_results.csv
# auc: 0.7604342443348282
# acc: 0.6969098277608915
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_75.01_69.22_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:15]/cv_3_test_results.csv
# auc: 0.7500694934434893
# acc: 0.6922492401215805
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.34_70.06_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:15]/cv_1_test_results.csv
# auc: 0.7634482592233647
# acc: 0.7006079027355623
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_76.98_70.31_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:15]/cv_0_test_results.csv
# auc: 0.7697803009572408
# acc: 0.7031408308004052
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_75.89_69.6_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:15]/cv_2_test_results.csv
# auc: 0.7589417214098915
# acc: 0.6960486322188449
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_75.99_69.25_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:15]/cv_4_test_results.csv
# auc: 0.7599314466401539
# acc: 0.6925025329280649
#
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.3_69.96_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.08_09:06]/cv_ensemble_test_results.csv
# auc: 0.7629540524229372
# acc: 0.699645390070922
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_75.35_69.48_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.08_09:06]/cv_3_test_results.csv
# auc: 0.7535217069797084
# acc: 0.6947821681864235
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.72_70.29_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.08_09:06]/cv_1_test_results.csv
# auc: 0.7672115491228358
# acc: 0.702887537993921
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_77.11_70.44_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.08_09:06]/cv_0_test_results.csv
# auc: 0.771092893858165
# acc: 0.7044072948328267
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_76.09_69.88_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.08_09:06]/cv_2_test_results.csv
# auc: 0.7609405369076173
# acc: 0.6988348530901722
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_76.2_69.73_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.08_09:06]/cv_4_test_results.csv
# auc: 0.7620035752463595
# acc: 0.6973150962512664
#
# cv_ensemble_test_results.csv
# cv_3_test_results.csv
# cv_1_test_results.csv
# cv_0_test_results.csv
# cv_2_test_results.csv
# cv_4_test_results.csv
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.66_70.16_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:24]/cv_ensemble_test_results.csv
# auc: 0.7666365511513533
# acc: 0.7015704154002027
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_75.93_69.63_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:24]/cv_3_test_results.csv
# auc: 0.7592962720457201
# acc: 0.6963019250253293
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.7_70.52_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:24]/cv_1_test_results.csv
# auc: 0.7669959539981603
# acc: 0.7051671732522796
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_77.12_70.16_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:24]/cv_0_test_results.csv
# auc: 0.7712349832922867
# acc: 0.7016210739614995
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_76.87_70.39_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:24]/cv_2_test_results.csv
# auc: 0.7687369698973662
# acc: 0.7039007092198581
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_76.69_70.09_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:24]/cv_4_test_results.csv
# auc: 0.7669185765232334
# acc: 0.7008611955420466
#
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.05_69.7_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:11]/cv_ensemble_test_results.csv
# auc: 0.760549726143694
# acc: 0.6969604863221884
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_75.07_69.28_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:11]/cv_3_test_results.csv
# auc: 0.7506702299328216
# acc: 0.6927558257345492
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.39_69.6_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:11]/cv_1_test_results.csv
# auc: 0.7639374548276883
# acc: 0.6960486322188449
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_76.9_70.34_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:11]/cv_0_test_results.csv
# auc: 0.7689946979828697
# acc: 0.7033941236068896
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_75.89_69.58_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:11]/cv_2_test_results.csv
# auc: 0.7589240077868059
# acc: 0.6957953394123607
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_76.02_69.68_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:11]/cv_4_test_results.csv
# auc: 0.7602222401882843
# acc: 0.6968085106382979
#
# cv_ensemble_test_results.csv
# cv_3_test_results.csv
# cv_1_test_results.csv
# cv_0_test_results.csv
# cv_2_test_results.csv
# cv_4_test_results.csv
# cv_ensemble_test_results.csv
# cv_3_test_results.csv
# cv_1_test_results.csv
# cv_0_test_results.csv
# cv_2_test_results.csv
# cv_4_test_results.csv
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.05_69.7_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:09]/cv_ensemble_test_results.csv
# auc: 0.7605497004766788
# acc: 0.6969604863221884
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_75.07_69.28_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:09]/cv_3_test_results.csv
# auc: 0.7506701015977459
# acc: 0.6927558257345492
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.39_69.6_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:09]/cv_1_test_results.csv
# auc: 0.7639374548276883
# acc: 0.6960486322188449
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_76.9_70.34_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:09]/cv_0_test_results.csv
# auc: 0.7689946979828697
# acc: 0.7033941236068896
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_75.89_69.58_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:09]/cv_2_test_results.csv
# auc: 0.7589240077868059
# acc: 0.6957953394123607
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_76.02_69.68_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.08_10:09]/cv_4_test_results.csv
# auc: 0.7602222401882843
# acc: 0.6968085106382979
#
# cv_ensemble_test_results.csv
# cv_3_test_results.csv
# cv_1_test_results.csv
# cv_0_test_results.csv
# cv_2_test_results.csv
# cv_4_test_results.csv
# cv_ensemble_test_results.csv
# cv_3_test_results.csv
# cv_1_test_results.csv
# cv_0_test_results.csv
# cv_2_test_results.csv
# cv_4_test_results.csv
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.76_70.17_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:20]/cv_ensemble_test_results.csv
# auc: 0.7675818746349291
# acc: 0.7017223910840933
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_75.99_69.58_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:20]/cv_3_test_results.csv
# auc: 0.7599338407017773
# acc: 0.6957953394123607
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.8_70.54_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:20]/cv_1_test_results.csv
# auc: 0.7679985996583331
# acc: 0.705420466058764
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_77.23_70.01_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:20]/cv_0_test_results.csv
# auc: 0.7723444628158632
# acc: 0.7001013171225937
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_76.99_70.26_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:20]/cv_2_test_results.csv
# auc: 0.769877958271325
# acc: 0.7026342451874367
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_76.78_70.47_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.08_12:20]/cv_4_test_results.csv
# auc: 0.7677545117273471
# acc: 0.704660587639311
#
# cv_ensemble_test_results.csv
# cv_3_test_results.csv
# cv_1_test_results.csv
# cv_0_test_results.csv
# cv_2_test_results.csv
# cv_4_test_results.csv
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.59_70.23_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.09_14:56]/cv_ensemble_test_results.csv
# auc: 0.7659187855940672
# acc: 0.7022796352583587
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_75.86_69.63_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.09_14:56]/cv_3_test_results.csv
# auc: 0.758607241024309
# acc: 0.6963019250253293
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.64_70.62_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.09_14:56]/cv_1_test_results.csv
# auc: 0.7663997308140872
# acc: 0.7061803444782169
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_77.04_70.04_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.09_14:56]/cv_0_test_results.csv
# auc: 0.7703796203154488
# acc: 0.700354609929078
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_76.76_70.47_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.09_14:56]/cv_2_test_results.csv
# auc: 0.7675851993180511
# acc: 0.704660587639311
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_76.66_70.39_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.09_14:56]/cv_4_test_results.csv
# auc: 0.7666221364984402
# acc: 0.7039007092198581
#
# cv_ensemble_test_results.csv
# cv_3_test_results.csv
# cv_1_test_results.csv
# cv_0_test_results.csv
# cv_2_test_results.csv
# cv_4_test_results.csv
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.05_69.7_cv_ensemble_test_results.csv
# file_path: ../feature_test/LOG_[06.08_09:13]/cv_ensemble_test_results.csv
# auc: 0.7605497004766788
# acc: 0.6969604863221884
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_75.07_69.28_cv_3_test_results.csv
# file_path: ../feature_test/LOG_[06.08_09:13]/cv_3_test_results.csv
# auc: 0.7506701015977459
# acc: 0.6927558257345492
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.39_69.6_cv_1_test_results.csv
# file_path: ../feature_test/LOG_[06.08_09:13]/cv_1_test_results.csv
# auc: 0.7639374548276883
# acc: 0.6960486322188449
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_76.9_70.34_cv_0_test_results.csv
# file_path: ../feature_test/LOG_[06.08_09:13]/cv_0_test_results.csv
# auc: 0.7689946979828697
# acc: 0.7033941236068896
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_75.89_69.58_cv_2_test_results.csv
# file_path: ../feature_test/LOG_[06.08_09:13]/cv_2_test_results.csv
# auc: 0.7589240077868059
# acc: 0.6957953394123607
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_76.02_69.68_cv_4_test_results.csv
# file_path: ../feature_test/LOG_[06.08_09:13]/cv_4_test_results.csv
# auc: 0.7602222401882843
# acc: 0.6968085106382979
#
# cv_ensemble_test_results.csv
# cv_3_test_results.csv
# cv_1_test_results.csv
# cv_0_test_results.csv
# cv_2_test_results.csv
# cv_4_test_results.csv
# cv_ensemble_test_results.csv
# cv_3_test_results.csv
# cv_1_test_results.csv
# cv_0_test_results.csv
# cv_2_test_results.csv
# cv_4_test_results.csv
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_77.7_70.76_cv_ensemble_test_results.csv
# file_path: ../split_test/LOG_[06.11_18:40]/cv_ensemble_test_results.csv
# auc: 0.7770310448109141
# acc: 0.7075987841945289
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_77.08_70.14_cv_3_test_results.csv
# file_path: ../split_test/LOG_[06.11_18:40]/cv_3_test_results.csv
# auc: 0.7707586707798441
# acc: 0.7013677811550152
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_77.73_71.0_cv_1_test_results.csv
# file_path: ../split_test/LOG_[06.11_18:40]/cv_1_test_results.csv
# auc: 0.7772906554643934
# acc: 0.7099797365754813
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_77.5_70.85_cv_0_test_results.csv
# file_path: ../split_test/LOG_[06.11_18:40]/cv_0_test_results.csv
# auc: 0.774972836356765
# acc: 0.7084599797365755
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_78.19_70.87_cv_2_test_results.csv
# file_path: ../split_test/LOG_[06.11_18:40]/cv_2_test_results.csv
# auc: 0.7818849618849619
# acc: 0.7087132725430598
#
# run_test_results.csv
# 745
# ../all_csvs/lstm_78.19_70.87_run_test_results.csv
# file_path: ../split_test/LOG_[06.11_18:40]/run_test_results.csv
# auc: 0.7818849618849619
# acc: 0.7087132725430598
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_78.02_70.95_cv_4_test_results.csv
# file_path: ../split_test/LOG_[06.11_18:40]/cv_4_test_results.csv
# auc: 0.7802480995686063
# acc: 0.7094731509625126
#
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.48_68.88_cv_ensemble_test_results.csv
# file_path: ../refactoring/LOG_[06.10_10:53]/cv_ensemble_test_results.csv
# auc: 0.7647756599363843
# acc: 0.6888044579533943
#
# cv_7_test_results.csv
# 745
# ../all_csvs/lstm_75.92_68.57_cv_7_test_results.csv
# file_path: ../refactoring/LOG_[06.10_10:53]/cv_7_test_results.csv
# auc: 0.7591646724450974
# acc: 0.6856636271529889
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_76.89_69.76_cv_3_test_results.csv
# file_path: ../refactoring/LOG_[06.10_10:53]/cv_3_test_results.csv
# auc: 0.76891771696246
# acc: 0.6975683890577508
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.79_69.22_cv_1_test_results.csv
# file_path: ../refactoring/LOG_[06.10_10:53]/cv_1_test_results.csv
# auc: 0.7678733112963496
# acc: 0.6922492401215805
#
# cv_8_test_results.csv
# 745
# ../all_csvs/lstm_77.11_69.66_cv_8_test_results.csv
# file_path: ../refactoring/LOG_[06.10_10:53]/cv_8_test_results.csv
# auc: 0.7710558557023384
# acc: 0.6965552178318136
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_76.5_68.36_cv_0_test_results.csv
# file_path: ../refactoring/LOG_[06.10_10:53]/cv_0_test_results.csv
# auc: 0.7649851265273062
# acc: 0.6836372847011145
#
# cv_6_test_results.csv
# 745
# ../all_csvs/lstm_76.45_68.87_cv_6_test_results.csv
# file_path: ../refactoring/LOG_[06.10_10:53]/cv_6_test_results.csv
# auc: 0.7645470999791473
# acc: 0.6887031408308004
#
# cv_5_test_results.csv
# 745
# ../all_csvs/lstm_75.47_67.81_cv_5_test_results.csv
# file_path: ../refactoring/LOG_[06.10_10:53]/cv_5_test_results.csv
# auc: 0.7546929015754301
# acc: 0.67806484295846
#
# cv_9_test_results.csv
# 745
# ../all_csvs/lstm_75.94_68.14_cv_9_test_results.csv
# file_path: ../refactoring/LOG_[06.10_10:53]/cv_9_test_results.csv
# auc: 0.7594056384422867
# acc: 0.6813576494427558
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_77.5_70.54_cv_2_test_results.csv
# file_path: ../refactoring/LOG_[06.10_10:53]/cv_2_test_results.csv
# auc: 0.7750336440597062
# acc: 0.705420466058764
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_76.21_67.88_cv_4_test_results.csv
# file_path: ../refactoring/LOG_[06.10_10:53]/cv_4_test_results.csv
# auc: 0.7620806323737224
# acc: 0.6788247213779128
#
# cv_ensemble_test_results.csv
# cv_3_test_results.csv
# cv_1_test_results.csv
# cv_0_test_results.csv
# cv_2_test_results.csv
# cv_4_test_results.csv
# cv_ensemble_test_results.csv
# 745
# ../all_csvs/lstm_76.35_68.69_cv_ensemble_test_results.csv
# file_path: ../refactoring/LOG_[06.10_10:07]/cv_ensemble_test_results.csv
# auc: 0.7634556200231492
# acc: 0.6868794326241136
#
# cv_7_test_results.csv
# 745
# ../all_csvs/lstm_75.6_68.87_cv_7_test_results.csv
# file_path: ../refactoring/LOG_[06.10_10:07]/cv_7_test_results.csv
# auc: 0.7559675877510954
# acc: 0.6887031408308004
#
# cv_3_test_results.csv
# 745
# ../all_csvs/lstm_77.0_69.12_cv_3_test_results.csv
# file_path: ../refactoring/LOG_[06.10_10:07]/cv_3_test_results.csv
# auc: 0.7699971002409959
# acc: 0.6912360688956434
#
# cv_1_test_results.csv
# 745
# ../all_csvs/lstm_76.52_69.12_cv_1_test_results.csv
# file_path: ../refactoring/LOG_[06.10_10:07]/cv_1_test_results.csv
# auc: 0.7652224571921323
# acc: 0.6912360688956434
#
# cv_8_test_results.csv
# 745
# ../all_csvs/lstm_77.03_69.66_cv_8_test_results.csv
# file_path: ../refactoring/LOG_[06.10_10:07]/cv_8_test_results.csv
# auc: 0.770342800360929
# acc: 0.6965552178318136
#
# cv_0_test_results.csv
# 745
# ../all_csvs/lstm_76.38_69.07_cv_0_test_results.csv
# file_path: ../refactoring/LOG_[06.10_10:07]/cv_0_test_results.csv
# auc: 0.7638355674378876
# acc: 0.6907294832826748
#
# cv_6_test_results.csv
# 745
# ../all_csvs/lstm_76.63_68.24_cv_6_test_results.csv
# file_path: ../refactoring/LOG_[06.10_10:07]/cv_6_test_results.csv
# auc: 0.7663172719269682
# acc: 0.682370820668693
#
# cv_5_test_results.csv
# 745
# ../all_csvs/lstm_75.07_66.46_cv_5_test_results.csv
# file_path: ../refactoring/LOG_[06.10_10:07]/cv_5_test_results.csv
# auc: 0.7506753494249448
# acc: 0.6646403242147924
#
# cv_9_test_results.csv
# 745
# ../all_csvs/lstm_75.69_68.62_cv_9_test_results.csv
# file_path: ../refactoring/LOG_[06.10_10:07]/cv_9_test_results.csv
# auc: 0.7569252392171033
# acc: 0.6861702127659575
#
# cv_2_test_results.csv
# 745
# ../all_csvs/lstm_77.38_69.53_cv_2_test_results.csv
# file_path: ../refactoring/LOG_[06.10_10:07]/cv_2_test_results.csv
# auc: 0.7737778301300904
# acc: 0.6952887537993921
#
# cv_4_test_results.csv
# 745
# ../all_csvs/lstm_76.15_68.19_cv_4_test_results.csv
# file_path: ../refactoring/LOG_[06.10_10:07]/cv_4_test_results.csv
# auc: 0.7614949965493444
# acc: 0.6818642350557245

# %%
json.load??
# Out:
# Signature:
# json.load(
#     fp,
#     *,
#     cls=None,
#     object_hook=None,
#     parse_float=None,
#     parse_int=None,
#     parse_constant=None,
#     object_pairs_hook=None,
#     **kw,
# )
# Source:
# def load(fp, *, cls=None, object_hook=None, parse_float=None,
#         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     a JSON document) to a Python object.
#
#     ``object_hook`` is an optional function that will be called with the
#     result of any object literal decode (a ``dict``). The return value of
#     ``object_hook`` will be used instead of the ``dict``. This feature
#     can be used to implement custom decoders (e.g. JSON-RPC class hinting).
#
#     ``object_pairs_hook`` is an optional function that will be called with the
#     result of any object literal decoded with an ordered list of pairs.  The
#     return value of ``object_pairs_hook`` will be used instead of the ``dict``.
#     This feature can be used to implement custom decoders.  If ``object_hook``
#     is also defined, the ``object_pairs_hook`` takes priority.
#
#     To use a custom ``JSONDecoder`` subclass, specify it with the ``cls``
#     kwarg; otherwise ``JSONDecoder`` is used.
#     """
#     return loads(fp.read(),
#         cls=cls, object_hook=object_hook,
#         parse_float=parse_float, parse_int=parse_int,
#         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
# File:      ~/anaconda3/envs/baseline_code/lib/python3.8/json/__init__.py
# Type:      function
